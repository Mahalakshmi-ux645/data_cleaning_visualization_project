# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('employee_data.csv')
df.head()
# Out:
#    Employee_ID    Name   Age Department   Salary  Experience
# 0          101    Ravi  25.0         IT  35000.0           2
# 1          102   Priya  28.0         HR  40000.0           4
# 2          103   Kiran  32.0    Finance  50000.0           7
# 3          104  Anjali  26.0         IT  38000.0           3
# 4          105   Rahul  35.0  Marketing  55000.0          10

# %%
df.isnull().sum()
# Out:
# Employee_ID    0
# Name           0
# Age            1
# Department     0
# Salary         1
# Experience     0
# dtype: int64

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["Salary"] = df["Salary"].fillna(df["Salary"].mean())

print("Missing values handled successfully")
print(df.isnull().sum())
# Out:
# Missing values handled successfully
# Employee_ID    0
# Name           0
# Age            0
# Department     0
# Salary         0
# Experience     0
# dtype: int64

# %%
print("Rows before removing duplicates:", len(df))

df.drop_duplicates(inplace=True)

print("Rows after removing duplicates:", len(df))
# Out:
# Rows before removing duplicates: 16
# Rows after removing duplicates: 15

# %%
df["Department"].value_counts().plot(kind="bar")
plt.title("Employees by Department")
plt.show()

# %%
df["Department"].value_counts().plot(kind="pie", autopct="%1.1f%%")
plt.title("Department Distribution")
plt.show()

# %%
df["Salary"].plot(kind="hist")
plt.title("Salary Distribution")
plt.show()

# %%
sns.boxplot(y=df["Salary"])
plt.title("Salary Outliers")
plt.show()
